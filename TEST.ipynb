# %%
import time
import talib
import numpy as np
import pandas as pd
import requests
from binance.client import Client
from binance.enums import *
from binance.exceptions import BinanceAPIException
from apscheduler.schedulers.blocking import BlockingScheduler

# ✅ Enter Your Binance Testnet API Key and Secret Here
API_KEY = "l1axguRUuSx0aXTuwprNcFNHNM7J5HeKfN0OKp85ABAQmH0oWCNci02MQfVB97aY"
API_SECRET = "EicJhiWluIhggMdByykWpAMklPKCLr3R47cj5nggnTZvBfvVVQzta8va60ekD6y7"

# ✅ Initialize Binance Testnet Client
try:
    client = Client(API_KEY, API_SECRET, testnet=True)  # Enable Testnet
    client.ping()  # Ensure API is reachable
    print("✅ Binance Testnet Connection Successful!")
except BinanceAPIException as e:
    print(f"❌ Binance API Error: {e}")
    exit()
except requests.exceptions.RequestException as e:
    print(f"❌ Network Error: {e}")
    exit()

# ✅ Function to Safely Call Binance API with Retry Mechanism
def safe_binance_call(func, *args, **kwargs):
    max_retries = 5
    retry_delay = 5

    for attempt in range(max_retries):
        try:
            return func(*args, **kwargs)
        except BinanceAPIException as e:
            if "502 Bad Gateway" in str(e):
                print(f"⚠️ Binance 502 Error (Attempt {attempt+1}/{max_retries}) - Retrying in {retry_delay}s...")
                time.sleep(retry_delay)
            else:
                print(f"❌ Binance API Exception: {e}")
                return None
        except requests.exceptions.RequestException as e:
            print(f"❌ Network Error: {e}")
            return None
    print("❌ Binance API Failed After Multiple Attempts!")
    return None

# ✅ Function to Fetch Historical Data
def get_historical_data(symbol, interval, lookback):
    klines = safe_binance_call(client.get_klines, symbol=symbol, interval=interval, limit=lookback)
    if not klines:
        return None
    
    df = pd.DataFrame(klines, columns=['time', 'open', 'high', 'low', 'close', 'volume', 
                                       'close_time', 'quote_asset_volume', 'num_trades', 
                                       'taker_buy_base_vol', 'taker_buy_quote_vol', 'ignore'])
    
    df[['open', 'high', 'low', 'close']] = df[['open', 'high', 'low', 'close']].astype(float)
    return df

# ✅ Function to Identify Candlestick Patterns
def identify_patterns(df):
    patterns = {
        'Hammer': talib.CDLHAMMER(df['open'], df['high'], df['low'], df['close']),
        'Engulfing': talib.CDLENGULFING(df['open'], df['high'], df['low'], df['close']),
        'Morning Star': talib.CDLMORNINGSTAR(df['open'], df['high'], df['low'], df['close']),
        'Evening Star': talib.CDLEVENINGSTAR(df['open'], df['high'], df['low'], df['close']),
        'Shooting Star': talib.CDLSHOOTINGSTAR(df['open'], df['high'], df['low'], df['close']),
        'Doji': talib.CDLDOJI(df['open'], df['high'], df['low'], df['close']),
        'Three White Soldiers': talib.CDL3WHITESOLDIERS(df['open'], df['high'], df['low'], df['close']),
        'Three Black Crows': talib.CDL3BLACKCROWS(df['open'], df['high'], df['low'], df['close']),
        'Bullish Harami': talib.CDLHARAMI(df['open'], df['high'], df['low'], df['close']),
        'Bearish Harami': talib.CDLHARAMICROSS(df['open'], df['high'], df['low'], df['close'])
    }
    
    signals = [key for key, val in patterns.items() if val.iloc[-1] != 0]
    return signals

# ✅ Function to Generate Trading Signals
def generate_signal(symbol):
    df = get_historical_data(symbol, Client.KLINE_INTERVAL_15MINUTE, 50)
    if df is None:
        return None, None

    patterns = identify_patterns(df)

    if patterns:
        last_close = df['close'].iloc[-1]
        
        if any(p in patterns for p in ['Hammer', 'Morning Star', 'Engulfing', 'Three White Soldiers', 'Bullish Harami']):
            return "LONG", last_close
        elif any(p in patterns for p in ['Shooting Star', 'Evening Star', 'Three Black Crows', 'Bearish Harami']):
            return "SHORT", last_close

    return None, None

# ✅ Function to Execute Trades on Testnet
def execute_trade(symbol):
    signal, entry_price = generate_signal(symbol)
    if signal:
        print(f"\n📊 {symbol} - {signal} Signal Detected at {entry_price}")
        
        stop_loss = entry_price * (0.97 if signal == "LONG" else 1.03)
        tp1 = entry_price * (1.02 if signal == "LONG" else 0.98)
        tp2 = entry_price * (1.04 if signal == "LONG" else 0.96)
        tp3 = entry_price * (1.06 if signal == "LONG" else 0.94)
        
        print(f"Entry: {entry_price}, Stop Loss: {stop_loss}, TP1: {tp1}, TP2: {tp2}, TP3: {tp3}")
        
        order_type = ORDER_TYPE_MARKET
        side = SIDE_BUY if signal == "LONG" else SIDE_SELL
        
        try:
            order = safe_binance_call(client.create_order,
                symbol=symbol,
                side=side,
                type=order_type,
                quantity=0.01  # Modify lot size for test
            )
            if order:
                print(f"✅ Trade Executed: {order}")
        except Exception as e:
            print(f"⚠️ Trade Execution Error: {e}")

# ✅ Function to Check Placed Trades
def check_trades(symbol):
    orders = safe_binance_call(client.get_all_orders, symbol=symbol)
    if orders:
        print("\n📜 Placed Trades:")
        for order in orders[-5:]:  # Show last 5 trades
            print(f"🔹 Order {order['orderId']} - {order['side']} {order['origQty']} at {order['price']} (Status: {order['status']})")

# ✅ Function to Scan and Trade the Top 100 USDT Pairs
def trading_bot():
    usdt_pairs = [s['symbol'] for s in safe_binance_call(client.get_exchange_info)['symbols'] if s['symbol'].endswith("USDT")]
    
    if not usdt_pairs:
        print("❌ No USDT pairs found!")
        return
    
    for symbol in usdt_pairs[:100]:  
        execute_trade(symbol)
        check_trades(symbol)
        time.sleep(2)

# ✅ Scheduler to Run the Bot Every 5 Minutes
scheduler = BlockingScheduler()
scheduler.add_job(trading_bot, 'interval', minutes=5)
print("🚀 Trading bot started... Press Ctrl+C to stop.")
scheduler.start()
# Out:
# ✅ Binance Testnet Connection Successful!
# 🚀 Trading bot started... Press Ctrl+C to stop.
#
# 📊 BTCUSDT - LONG Signal Detected at 90348.36
# Entry: 90348.36, Stop Loss: 87637.9092, TP1: 92155.3272, TP2: 93962.2944, TP3: 95769.26160000001
# ✅ Trade Executed: {'symbol': 'BTCUSDT', 'orderId': 454138, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ76a2c21828ea952b9fc9ba', 'transactTime': 1741268343970, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '903.47990000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741268343970, 'fills': [{'price': '90347.99000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'BTC', 'tradeId': 104345}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 454138 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 ETHUSDT - LONG Signal Detected at 2264.33
# Entry: 2264.33, Stop Loss: 2196.4001, TP1: 2309.6166, TP2: 2354.9032, TP3: 2400.1898
# ✅ Trade Executed: {'symbol': 'ETHUSDT', 'orderId': 397131, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ4516ed7d1d6eb962c49d92', 'transactTime': 1741268347163, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '22.64430000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741268347163, 'fills': [{'price': '2264.43000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'ETH', 'tradeId': 106911}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 397131 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 XRPUSDT - LONG Signal Detected at 2.6173
# Entry: 2.6173, Stop Loss: 2.538781, TP1: 2.669646, TP2: 2.721992, TP3: 2.774338
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOTAUSDT - LONG Signal Detected at 0.2178
# Entry: 0.2178, Stop Loss: 0.21126599999999998, TP1: 0.222156, TP2: 0.226512, TP3: 0.23086800000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 VETUSDT - LONG Signal Detected at 0.02872
# Entry: 0.02872, Stop Loss: 0.0278584, TP1: 0.029294399999999998, TP2: 0.0298688, TP3: 0.0304432
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 USDCUSDT - LONG Signal Detected at 1.0
# Entry: 1.0, Stop Loss: 0.97, TP1: 1.02, TP2: 1.04, TP3: 1.06
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 HOTUSDT - LONG Signal Detected at 0.001306
# Entry: 0.001306, Stop Loss: 0.00126682, TP1: 0.00133212, TP2: 0.0013582400000000001, TP3: 0.00138436
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZRXUSDT - LONG Signal Detected at 0.28
# Entry: 0.28, Stop Loss: 0.2716, TP1: 0.2856, TP2: 0.2912, TP3: 0.29680000000000006
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZECUSDT - LONG Signal Detected at 35.5
# Entry: 35.5, Stop Loss: 34.435, TP1: 36.21, TP2: 36.92, TP3: 37.63
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 DUSKUSDT - LONG Signal Detected at 0.1137
# Entry: 0.1137, Stop Loss: 0.110289, TP1: 0.115974, TP2: 0.118248, TP3: 0.120522
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ANKRUSDT - LONG Signal Detected at 0.01943
# Entry: 0.01943, Stop Loss: 0.0188471, TP1: 0.0198186, TP2: 0.0202072, TP3: 0.0205958
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 MTLUSDT - LONG Signal Detected at 0.823
# Entry: 0.823, Stop Loss: 0.79831, TP1: 0.83946, TP2: 0.85592, TP3: 0.87238
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 FUNUSDT - LONG Signal Detected at 0.002297
# Entry: 0.002297, Stop Loss: 0.00222809, TP1: 0.00234294, TP2: 0.00238888, TP3: 0.0024348200000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CHZUSDT - LONG Signal Detected at 0.05
# Entry: 0.05, Stop Loss: 0.0485, TP1: 0.051000000000000004, TP2: 0.052000000000000005, TP3: 0.053000000000000005
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 XTZUSDT - LONG Signal Detected at 0.783
# Entry: 0.783, Stop Loss: 0.75951, TP1: 0.79866, TP2: 0.81432, TP3: 0.82998
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 RVNUSDT - LONG Signal Detected at 0.01306
# Entry: 0.01306, Stop Loss: 0.0126682, TP1: 0.0133212, TP2: 0.013582400000000001, TP3: 0.013843600000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 STXUSDT - LONG Signal Detected at 0.731
# Entry: 0.731, Stop Loss: 0.70907, TP1: 0.74562, TP2: 0.76024, TP3: 0.77486
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 KAVAUSDT - LONG Signal Detected at 0.4534
# Entry: 0.4534, Stop Loss: 0.439798, TP1: 0.46246800000000005, TP2: 0.47153600000000007, TP3: 0.48060400000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOTXUSDT - LONG Signal Detected at 0.01681
# Entry: 0.01681, Stop Loss: 0.0163057, TP1: 0.0171462, TP2: 0.0174824, TP3: 0.0178186
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 COTIUSDT - LONG Signal Detected at 0.07733
# Entry: 0.07733, Stop Loss: 0.0750101, TP1: 0.07887659999999999, TP2: 0.0804232, TP3: 0.0819698
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 STPTUSDT - LONG Signal Detected at 0.0754
# Entry: 0.0754, Stop Loss: 0.073138, TP1: 0.07690799999999999, TP2: 0.078416, TP3: 0.079924
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 SOLUSDT - LONG Signal Detected at 148.48
# Entry: 148.48, Stop Loss: 144.0256, TP1: 151.4496, TP2: 154.4192, TP3: 157.3888
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 CHRUSDT - LONG Signal Detected at 0.1111
# Entry: 0.1111, Stop Loss: 0.107767, TP1: 0.113322, TP2: 0.11554400000000001, TP3: 0.11776600000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ARDRUSDT - LONG Signal Detected at 0.06351
# Entry: 0.06351, Stop Loss: 0.0616047, TP1: 0.0647802, TP2: 0.0660504, TP3: 0.0673206
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 KNCUSDT - LONG Signal Detected at 0.371
# Entry: 0.371, Stop Loss: 0.35986999999999997, TP1: 0.37842, TP2: 0.38584, TP3: 0.39326
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZENUSDT - LONG Signal Detected at 11.32
# Entry: 11.32, Stop Loss: 10.9804, TP1: 11.5464, TP2: 11.7728, TP3: 11.9992
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 DGBUSDT - LONG Signal Detected at 0.00843
# Entry: 0.00843, Stop Loss: 0.0081771, TP1: 0.0085986, TP2: 0.008767200000000001, TP3: 0.0089358
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📜 Placed Trades:
# 🔹 Order 39132 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 DCRUSDT - LONG Signal Detected at 12.12
# Entry: 12.12, Stop Loss: 11.7564, TP1: 12.3624, TP2: 12.6048, TP3: 12.847199999999999
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 STORJUSDT - LONG Signal Detected at 0.3141
# Entry: 0.3141, Stop Loss: 0.304677, TP1: 0.320382, TP2: 0.326664, TP3: 0.332946
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📜 Placed Trades:
# 🔹 Order 49348 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 KMDUSDT - LONG Signal Detected at 0.1769
# Entry: 0.1769, Stop Loss: 0.171593, TP1: 0.18043800000000002, TP2: 0.183976, TP3: 0.18751400000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 JSTUSDT - LONG Signal Detected at 0.03228
# Entry: 0.03228, Stop Loss: 0.0313116, TP1: 0.032925600000000006, TP2: 0.0335712, TP3: 0.034216800000000006
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 SANDUSDT - LONG Signal Detected at 0.3195
# Entry: 0.3195, Stop Loss: 0.309915, TP1: 0.32589, TP2: 0.33228, TP3: 0.33867
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 NMRUSDT - LONG Signal Detected at 9.15
# Entry: 9.15, Stop Loss: 8.8755, TP1: 9.333, TP2: 9.516, TP3: 9.699000000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📜 Placed Trades:
# 🔹 Order 454138 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 397131 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 BNBUSDT - LONG Signal Detected at 600.26
# Entry: 600.26, Stop Loss: 582.2522, TP1: 612.2652, TP2: 624.2704, TP3: 636.2756
# ✅ Trade Executed: {'symbol': 'BNBUSDT', 'orderId': 183127, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ370eb03f66ad73f9612294', 'transactTime': 1741268649486, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '6.00130000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741268649486, 'fills': [{'price': '600.13000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'BNB', 'tradeId': 33995}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 183127 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 XRPUSDT - LONG Signal Detected at 2.6178
# Entry: 2.6178, Stop Loss: 2.539266, TP1: 2.670156, TP2: 2.722512, TP3: 2.774868
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 QTUMUSDT - LONG Signal Detected at 2.355
# Entry: 2.355, Stop Loss: 2.28435, TP1: 2.4021, TP2: 2.4492000000000003, TP3: 2.4963
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOTAUSDT - LONG Signal Detected at 0.2175
# Entry: 0.2175, Stop Loss: 0.210975, TP1: 0.22185, TP2: 0.2262, TP3: 0.23055
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ETCUSDT - LONG Signal Detected at 20.46
# Entry: 20.46, Stop Loss: 19.8462, TP1: 20.869200000000003, TP2: 21.2784, TP3: 21.687600000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 VETUSDT - LONG Signal Detected at 0.02868
# Entry: 0.02868, Stop Loss: 0.0278196, TP1: 0.0292536, TP2: 0.0298272, TP3: 0.030400800000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 HOTUSDT - LONG Signal Detected at 0.001306
# Entry: 0.001306, Stop Loss: 0.00126682, TP1: 0.00133212, TP2: 0.0013582400000000001, TP3: 0.00138436
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZRXUSDT - LONG Signal Detected at 0.2794
# Entry: 0.2794, Stop Loss: 0.271018, TP1: 0.28498799999999996, TP2: 0.290576, TP3: 0.296164
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BATUSDT - LONG Signal Detected at 0.1615
# Entry: 0.1615, Stop Loss: 0.156655, TP1: 0.16473000000000002, TP2: 0.16796, TP3: 0.17119
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOSTUSDT - LONG Signal Detected at 0.004459
# Entry: 0.004459, Stop Loss: 0.00432523, TP1: 0.004548180000000001, TP2: 0.00463736, TP3: 0.00472654
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DASHUSDT - LONG Signal Detected at 24.81
# Entry: 24.81, Stop Loss: 24.0657, TP1: 25.3062, TP2: 25.8024, TP3: 26.2986
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 ENJUSDT - LONG Signal Detected at 0.104
# Entry: 0.104, Stop Loss: 0.10088, TP1: 0.10608, TP2: 0.10815999999999999, TP3: 0.11024
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
# ❌ Network Error: HTTPSConnectionPool(host='testnet.binance.vision', port=443): Read timed out. (read timeout=10)
#
# 📊 ALGOUSDT - LONG Signal Detected at 0.2477
# Entry: 0.2477, Stop Loss: 0.240269, TP1: 0.252654, TP2: 0.257608, TP3: 0.262562
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 COSUSDT - LONG Signal Detected at 0.004145
# Entry: 0.004145, Stop Loss: 0.00402065, TP1: 0.004227900000000001, TP2: 0.0043108, TP3: 0.0043937
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 WANUSDT - LONG Signal Detected at 0.1219
# Entry: 0.1219, Stop Loss: 0.11824299999999999, TP1: 0.12433799999999999, TP2: 0.126776, TP3: 0.129214
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CVCUSDT - LONG Signal Detected at 0.1065
# Entry: 0.1065, Stop Loss: 0.103305, TP1: 0.10863, TP2: 0.11076, TP3: 0.11289
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CHZUSDT - LONG Signal Detected at 0.0499
# Entry: 0.0499, Stop Loss: 0.048403, TP1: 0.050898, TP2: 0.051896000000000005, TP3: 0.052894000000000004
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BANDUSDT - LONG Signal Detected at 0.899
# Entry: 0.899, Stop Loss: 0.87203, TP1: 0.91698, TP2: 0.93496, TP3: 0.9529400000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ARPAUSDT - LONG Signal Detected at 0.0307
# Entry: 0.0307, Stop Loss: 0.029779, TP1: 0.031314, TP2: 0.031928000000000005, TP3: 0.032542
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOTXUSDT - LONG Signal Detected at 0.01679
# Entry: 0.01679, Stop Loss: 0.0162863, TP1: 0.0171258, TP2: 0.0174616, TP3: 0.0177974
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 TROYUSDT - LONG Signal Detected at 0.001309
# Entry: 0.001309, Stop Loss: 0.00126973, TP1: 0.00133518, TP2: 0.00136136, TP3: 0.00138754
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LSKUSDT - LONG Signal Detected at 0.615
# Entry: 0.615, Stop Loss: 0.59655, TP1: 0.6273, TP2: 0.6396000000000001, TP3: 0.6519
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LTOUSDT - LONG Signal Detected at 0.0703
# Entry: 0.0703, Stop Loss: 0.068191, TP1: 0.071706, TP2: 0.07311200000000001, TP3: 0.074518
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 SOLUSDT - LONG Signal Detected at 147.49
# Entry: 147.49, Stop Loss: 143.0653, TP1: 150.43980000000002, TP2: 153.3896, TP3: 156.3394
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 CTSIUSDT - LONG Signal Detected at 0.0831
# Entry: 0.0831, Stop Loss: 0.080607, TP1: 0.08476199999999999, TP2: 0.086424, TP3: 0.088086
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 HIVEUSDT - LONG Signal Detected at 0.2654
# Entry: 0.2654, Stop Loss: 0.257438, TP1: 0.270708, TP2: 0.27601600000000004, TP3: 0.281324
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CHRUSDT - LONG Signal Detected at 0.1109
# Entry: 0.1109, Stop Loss: 0.107573, TP1: 0.113118, TP2: 0.11533600000000001, TP3: 0.117554
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LRCUSDT - LONG Signal Detected at 0.1128
# Entry: 0.1128, Stop Loss: 0.109416, TP1: 0.115056, TP2: 0.117312, TP3: 0.11956800000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 COMPUSDT - LONG Signal Detected at 50.77
# Entry: 50.77, Stop Loss: 49.246900000000004, TP1: 51.7854, TP2: 52.8008, TP3: 53.81620000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 SCUSDT - LONG Signal Detected at 0.003509
# Entry: 0.003509, Stop Loss: 0.0034037299999999998, TP1: 0.00357918, TP2: 0.00364936, TP3: 0.0037195400000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZENUSDT - LONG Signal Detected at 11.28
# Entry: 11.28, Stop Loss: 10.9416, TP1: 11.5056, TP2: 11.7312, TP3: 11.9568
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 VTHOUSDT - LONG Signal Detected at 0.00272
# Entry: 0.00272, Stop Loss: 0.0026384, TP1: 0.0027744, TP2: 0.0028288000000000002, TP3: 0.0028832000000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 SXPUSDT - LONG Signal Detected at 0.2102
# Entry: 0.2102, Stop Loss: 0.203894, TP1: 0.214404, TP2: 0.218608, TP3: 0.222812
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📜 Placed Trades:
# 🔹 Order 39132 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 STORJUSDT - LONG Signal Detected at 0.3131
# Entry: 0.3131, Stop Loss: 0.303707, TP1: 0.319362, TP2: 0.325624, TP3: 0.331886
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 MANAUSDT - LONG Signal Detected at 0.2872
# Entry: 0.2872, Stop Loss: 0.278584, TP1: 0.29294400000000004, TP2: 0.298688, TP3: 0.30443200000000004
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 YFIUSDT - LONG Signal Detected at 5498.0
# Entry: 5498.0, Stop Loss: 5333.0599999999995, TP1: 5607.96, TP2: 5717.92, TP3: 5827.88
# ✅ Trade Executed: {'symbol': 'YFIUSDT', 'orderId': 49771, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ1aaeb0330af9c04661edcd', 'transactTime': 1741268918893, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '55.00000000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741268918893, 'fills': [{'price': '5500.00000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'YFI', 'tradeId': 5962}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 49348 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 49771 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 BALUSDT - LONG Signal Detected at 1.693
# Entry: 1.693, Stop Loss: 1.64221, TP1: 1.72686, TP2: 1.76072, TP3: 1.79458
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 DOTUSDT - LONG Signal Detected at 4.498
# Entry: 4.498, Stop Loss: 4.36306, TP1: 4.587960000000001, TP2: 4.67792, TP3: 4.767880000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 LUNAUSDT - LONG Signal Detected at 0.2122
# Entry: 0.2122, Stop Loss: 0.205834, TP1: 0.216444, TP2: 0.220688, TP3: 0.22493200000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
# Execution of job "trading_bot (trigger: interval[0:05:00], next run at: 2025-03-06 19:19:02 IST)" skipped: maximum number of running instances reached (1)
# 📜 Placed Trades:
# 🔹 Order 454138 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 457107 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 ETHUSDT - LONG Signal Detected at 2255.0
# Entry: 2255.0, Stop Loss: 2187.35, TP1: 2300.1, TP2: 2345.2000000000003, TP3: 2390.3
# ✅ Trade Executed: {'symbol': 'ETHUSDT', 'orderId': 400610, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJc07835411376ac7adbd2e', 'transactTime': 1741269245948, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '22.54980000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741269245948, 'fills': [{'price': '2254.98000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'ETH', 'tradeId': 108176}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 397131 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 399235 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 400610 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 183127 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 XRPUSDT - LONG Signal Detected at 2.6134
# Entry: 2.6134, Stop Loss: 2.534998, TP1: 2.665668, TP2: 2.717936, TP3: 2.770204
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 NEOUSDT - LONG Signal Detected at 9.14
# Entry: 9.14, Stop Loss: 8.8658, TP1: 9.3228, TP2: 9.505600000000001, TP3: 9.688400000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 QTUMUSDT - LONG Signal Detected at 2.353
# Entry: 2.353, Stop Loss: 2.28241, TP1: 2.4000600000000003, TP2: 2.4471200000000004, TP3: 2.4941800000000005
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ICXUSDT - LONG Signal Detected at 0.1124
# Entry: 0.1124, Stop Loss: 0.109028, TP1: 0.114648, TP2: 0.116896, TP3: 0.119144
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 NULSUSDT - LONG Signal Detected at 0.1538
# Entry: 0.1538, Stop Loss: 0.14918599999999999, TP1: 0.156876, TP2: 0.159952, TP3: 0.163028
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 USDCUSDT - LONG Signal Detected at 1.0
# Entry: 1.0, Stop Loss: 0.97, TP1: 1.02, TP2: 1.04, TP3: 1.06
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LINKUSDT - LONG Signal Detected at 16.91
# Entry: 16.91, Stop Loss: 16.4027, TP1: 17.2482, TP2: 17.5864, TP3: 17.9246
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 ONGUSDT - LONG Signal Detected at 0.2352
# Entry: 0.2352, Stop Loss: 0.22814399999999999, TP1: 0.239904, TP2: 0.244608, TP3: 0.249312
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 HOTUSDT - LONG Signal Detected at 0.001303
# Entry: 0.001303, Stop Loss: 0.0012639099999999998, TP1: 0.00132906, TP2: 0.00135512, TP3: 0.0013811799999999999
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZILUSDT - LONG Signal Detected at 0.01301
# Entry: 0.01301, Stop Loss: 0.012619700000000001, TP1: 0.013270200000000001, TP2: 0.013530400000000001, TP3: 0.013790600000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZRXUSDT - LONG Signal Detected at 0.2792
# Entry: 0.2792, Stop Loss: 0.270824, TP1: 0.284784, TP2: 0.290368, TP3: 0.295952
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BATUSDT - LONG Signal Detected at 0.1615
# Entry: 0.1615, Stop Loss: 0.156655, TP1: 0.16473000000000002, TP2: 0.16796, TP3: 0.17119
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZECUSDT - LONG Signal Detected at 35.49
# Entry: 35.49, Stop Loss: 34.4253, TP1: 36.1998, TP2: 36.909600000000005, TP3: 37.619400000000006
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 IOSTUSDT - LONG Signal Detected at 0.004455
# Entry: 0.004455, Stop Loss: 0.00432135, TP1: 0.0045441, TP2: 0.0046332, TP3: 0.0047223
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ENJUSDT - LONG Signal Detected at 0.104
# Entry: 0.104, Stop Loss: 0.10088, TP1: 0.10608, TP2: 0.10815999999999999, TP3: 0.11024
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ATOMUSDT - LONG Signal Detected at 4.381
# Entry: 4.381, Stop Loss: 4.24957, TP1: 4.4686200000000005, TP2: 4.556240000000001, TP3: 4.64386
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 TFUELUSDT - LONG Signal Detected at 0.04275
# Entry: 0.04275, Stop Loss: 0.041467500000000004, TP1: 0.043605000000000005, TP2: 0.044460000000000006, TP3: 0.04531500000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ALGOUSDT - LONG Signal Detected at 0.2477
# Entry: 0.2477, Stop Loss: 0.240269, TP1: 0.252654, TP2: 0.257608, TP3: 0.262562
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 WANUSDT - LONG Signal Detected at 0.1215
# Entry: 0.1215, Stop Loss: 0.11785499999999999, TP1: 0.12393, TP2: 0.12636, TP3: 0.12879000000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CVCUSDT - LONG Signal Detected at 0.1064
# Entry: 0.1064, Stop Loss: 0.103208, TP1: 0.108528, TP2: 0.110656, TP3: 0.112784
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CHZUSDT - LONG Signal Detected at 0.0499
# Entry: 0.0499, Stop Loss: 0.048403, TP1: 0.050898, TP2: 0.051896000000000005, TP3: 0.052894000000000004
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BANDUSDT - LONG Signal Detected at 0.898
# Entry: 0.898, Stop Loss: 0.87106, TP1: 0.91596, TP2: 0.9339200000000001, TP3: 0.9518800000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 HBARUSDT - LONG Signal Detected at 0.24392
# Entry: 0.24392, Stop Loss: 0.2366024, TP1: 0.2487984, TP2: 0.2536768, TP3: 0.2585552
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ARPAUSDT - LONG Signal Detected at 0.03077
# Entry: 0.03077, Stop Loss: 0.0298469, TP1: 0.0313854, TP2: 0.0320008, TP3: 0.0326162
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BCHUSDT - LONG Signal Detected at 390.5
# Entry: 390.5, Stop Loss: 378.78499999999997, TP1: 398.31, TP2: 406.12, TP3: 413.93
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 TROYUSDT - LONG Signal Detected at 0.001312
# Entry: 0.001312, Stop Loss: 0.00127264, TP1: 0.00133824, TP2: 0.0013644800000000002, TP3: 0.00139072
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LSKUSDT - LONG Signal Detected at 0.615
# Entry: 0.615, Stop Loss: 0.59655, TP1: 0.6273, TP2: 0.6396000000000001, TP3: 0.6519
# ❌ Network Error: HTTPSConnectionPool(host='testnet.binance.vision', port=443): Read timed out. (read timeout=10)
#
# 📊 MBLUSDT - LONG Signal Detected at 0.002388
# Entry: 0.002388, Stop Loss: 0.00231636, TP1: 0.00243576, TP2: 0.00248352, TP3: 0.00253128
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 STPTUSDT - LONG Signal Detected at 0.07539
# Entry: 0.07539, Stop Loss: 0.0731283, TP1: 0.0768978, TP2: 0.0784056, TP3: 0.07991340000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 SOLUSDT - LONG Signal Detected at 147.0
# Entry: 147.0, Stop Loss: 142.59, TP1: 149.94, TP2: 152.88, TP3: 155.82000000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 HIVEUSDT - LONG Signal Detected at 0.2652
# Entry: 0.2652, Stop Loss: 0.257244, TP1: 0.270504, TP2: 0.275808, TP3: 0.28111200000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CHRUSDT - LONG Signal Detected at 0.1109
# Entry: 0.1109, Stop Loss: 0.107573, TP1: 0.113118, TP2: 0.11533600000000001, TP3: 0.117554
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LRCUSDT - LONG Signal Detected at 0.1125
# Entry: 0.1125, Stop Loss: 0.109125, TP1: 0.11475, TP2: 0.117, TP3: 0.11925000000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 COMPUSDT - LONG Signal Detected at 50.6
# Entry: 50.6, Stop Loss: 49.082, TP1: 51.612, TP2: 52.624, TP3: 53.636
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 SCUSDT - LONG Signal Detected at 0.003502
# Entry: 0.003502, Stop Loss: 0.0033969399999999998, TP1: 0.00357204, TP2: 0.0036420800000000002, TP3: 0.00371212
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 VTHOUSDT - LONG Signal Detected at 0.002719
# Entry: 0.002719, Stop Loss: 0.00263743, TP1: 0.00277338, TP2: 0.0028277600000000003, TP3: 0.00288214
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📜 Placed Trades:
# 🔹 Order 39132 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 49348 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 49771 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 CRVUSDT - LONG Signal Detected at 0.433
# Entry: 0.433, Stop Loss: 0.42001, TP1: 0.44166, TP2: 0.45032, TP3: 0.45898
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LUNAUSDT - LONG Signal Detected at 0.2117
# Entry: 0.2117, Stop Loss: 0.205349, TP1: 0.21593400000000001, TP2: 0.220168, TP3: 0.22440200000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
# Execution of job "trading_bot (trigger: interval[0:05:00], next run at: 2025-03-06 19:29:02 IST)" skipped: maximum number of running instances reached (1)
# 📜 Placed Trades:
# 🔹 Order 454138 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 457107 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 397131 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 399235 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 400610 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 183127 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 LTCUSDT - LONG Signal Detected at 105.89
# Entry: 105.89, Stop Loss: 102.7133, TP1: 108.0078, TP2: 110.1256, TP3: 112.24340000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 QTUMUSDT - LONG Signal Detected at 2.345
# Entry: 2.345, Stop Loss: 2.2746500000000003, TP1: 2.3919, TP2: 2.4388, TP3: 2.4857000000000005
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ADAUSDT - LONG Signal Detected at 0.9332
# Entry: 0.9332, Stop Loss: 0.905204, TP1: 0.951864, TP2: 0.9705280000000001, TP3: 0.9891920000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 XLMUSDT - LONG Signal Detected at 0.3039
# Entry: 0.3039, Stop Loss: 0.294783, TP1: 0.30997800000000003, TP2: 0.316056, TP3: 0.32213400000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ONTUSDT - LONG Signal Detected at 0.1591
# Entry: 0.1591, Stop Loss: 0.154327, TP1: 0.16228199999999998, TP2: 0.165464, TP3: 0.168646
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ICXUSDT - LONG Signal Detected at 0.1122
# Entry: 0.1122, Stop Loss: 0.10883399999999999, TP1: 0.11444399999999999, TP2: 0.116688, TP3: 0.118932
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 USDCUSDT - LONG Signal Detected at 1.0
# Entry: 1.0, Stop Loss: 0.97, TP1: 1.02, TP2: 1.04, TP3: 1.06
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 HOTUSDT - LONG Signal Detected at 0.001312
# Entry: 0.001312, Stop Loss: 0.00127264, TP1: 0.00133824, TP2: 0.0013644800000000002, TP3: 0.00139072
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZILUSDT - LONG Signal Detected at 0.01301
# Entry: 0.01301, Stop Loss: 0.012619700000000001, TP1: 0.013270200000000001, TP2: 0.013530400000000001, TP3: 0.013790600000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZRXUSDT - LONG Signal Detected at 0.2788
# Entry: 0.2788, Stop Loss: 0.270436, TP1: 0.284376, TP2: 0.289952, TP3: 0.295528
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 FETUSDT - LONG Signal Detected at 0.637
# Entry: 0.637, Stop Loss: 0.6178899999999999, TP1: 0.64974, TP2: 0.6624800000000001, TP3: 0.67522
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZECUSDT - LONG Signal Detected at 35.47
# Entry: 35.47, Stop Loss: 34.405899999999995, TP1: 36.1794, TP2: 36.8888, TP3: 37.5982
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 CELRUSDT - LONG Signal Detected at 0.01181
# Entry: 0.01181, Stop Loss: 0.0114557, TP1: 0.0120462, TP2: 0.012282399999999999, TP3: 0.0125186
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ONEUSDT - LONG Signal Detected at 0.01367
# Entry: 0.01367, Stop Loss: 0.0132599, TP1: 0.0139434, TP2: 0.0142168, TP3: 0.0144902
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 WINUSDT - LONG Signal Detected at 6.21e-05
# Entry: 6.21e-05, Stop Loss: 6.0237000000000006e-05, TP1: 6.3342e-05, TP2: 6.4584e-05, TP3: 6.5826e-05
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 COSUSDT - LONG Signal Detected at 0.004135
# Entry: 0.004135, Stop Loss: 0.00401095, TP1: 0.0042177, TP2: 0.0043004, TP3: 0.0043831
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 MTLUSDT - LONG Signal Detected at 0.821
# Entry: 0.821, Stop Loss: 0.7963699999999999, TP1: 0.8374199999999999, TP2: 0.8538399999999999, TP3: 0.87026
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DENTUSDT - LONG Signal Detected at 0.000819
# Entry: 0.000819, Stop Loss: 0.0007944299999999999, TP1: 0.0008353799999999999, TP2: 0.00085176, TP3: 0.00086814
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BANDUSDT - LONG Signal Detected at 0.9
# Entry: 0.9, Stop Loss: 0.873, TP1: 0.918, TP2: 0.936, TP3: 0.9540000000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 XTZUSDT - LONG Signal Detected at 0.78
# Entry: 0.78, Stop Loss: 0.7566, TP1: 0.7956000000000001, TP2: 0.8112, TP3: 0.8268000000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 STXUSDT - LONG Signal Detected at 0.728
# Entry: 0.728, Stop Loss: 0.70616, TP1: 0.74256, TP2: 0.75712, TP3: 0.77168
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 KAVAUSDT - LONG Signal Detected at 0.4531
# Entry: 0.4531, Stop Loss: 0.439507, TP1: 0.462162, TP2: 0.47122400000000003, TP3: 0.48028600000000005
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CTXCUSDT - LONG Signal Detected at 0.1539
# Entry: 0.1539, Stop Loss: 0.149283, TP1: 0.156978, TP2: 0.160056, TP3: 0.16313400000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 FTTUSDT - LONG Signal Detected at 1.4918
# Entry: 1.4918, Stop Loss: 1.447046, TP1: 1.521636, TP2: 1.551472, TP3: 1.5813080000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 LSKUSDT - LONG Signal Detected at 0.615
# Entry: 0.615, Stop Loss: 0.59655, TP1: 0.6273, TP2: 0.6396000000000001, TP3: 0.6519
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BNTUSDT - LONG Signal Detected at 0.4683
# Entry: 0.4683, Stop Loss: 0.45425099999999996, TP1: 0.477666, TP2: 0.487032, TP3: 0.496398
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CTSIUSDT - LONG Signal Detected at 0.0832
# Entry: 0.0832, Stop Loss: 0.080704, TP1: 0.084864, TP2: 0.086528, TP3: 0.088192
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CHRUSDT - LONG Signal Detected at 0.1111
# Entry: 0.1111, Stop Loss: 0.107767, TP1: 0.113322, TP2: 0.11554400000000001, TP3: 0.11776600000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 KNCUSDT - LONG Signal Detected at 0.3697
# Entry: 0.3697, Stop Loss: 0.35860899999999996, TP1: 0.377094, TP2: 0.384488, TP3: 0.391882
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 VTHOUSDT - LONG Signal Detected at 0.002726
# Entry: 0.002726, Stop Loss: 0.00264422, TP1: 0.0027805200000000003, TP2: 0.00283504, TP3: 0.0028895600000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DGBUSDT - LONG Signal Detected at 0.00845
# Entry: 0.00845, Stop Loss: 0.008196499999999999, TP1: 0.008619, TP2: 0.008787999999999999, TP3: 0.008957
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📜 Placed Trades:
# 🔹 Order 39132 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 DCRUSDT - LONG Signal Detected at 12.06
# Entry: 12.06, Stop Loss: 11.6982, TP1: 12.301200000000001, TP2: 12.5424, TP3: 12.783600000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📜 Placed Trades:
# 🔹 Order 49348 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 49771 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 BALUSDT - LONG Signal Detected at 1.688
# Entry: 1.688, Stop Loss: 1.63736, TP1: 1.72176, TP2: 1.75552, TP3: 1.78928
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 KMDUSDT - LONG Signal Detected at 0.1762
# Entry: 0.1762, Stop Loss: 0.17091399999999998, TP1: 0.179724, TP2: 0.183248, TP3: 0.186772
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 NMRUSDT - LONG Signal Detected at 9.12
# Entry: 9.12, Stop Loss: 8.8464, TP1: 9.302399999999999, TP2: 9.4848, TP3: 9.6672
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 PAXGUSDT - LONG Signal Detected at 2916.0
# Entry: 2916.0, Stop Loss: 2828.52, TP1: 2974.32, TP2: 3032.6400000000003, TP3: 3090.96
# ✅ Trade Executed: {'symbol': 'PAXGUSDT', 'orderId': 13707, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ9006f4650585ea2e9e8eb8', 'transactTime': 1741270114456, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '29.18000000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741270114456, 'fills': [{'price': '2918.00000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'PAXG', 'tradeId': 358}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 13706 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13707 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 454138 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 457107 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 397131 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 399235 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 400610 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 183127 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 LTCUSDT - LONG Signal Detected at 105.87
# Entry: 105.87, Stop Loss: 102.6939, TP1: 107.98740000000001, TP2: 110.10480000000001, TP3: 112.22220000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 NEOUSDT - LONG Signal Detected at 9.14
# Entry: 9.14, Stop Loss: 8.8658, TP1: 9.3228, TP2: 9.505600000000001, TP3: 9.688400000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 ADAUSDT - LONG Signal Detected at 0.9323
# Entry: 0.9323, Stop Loss: 0.904331, TP1: 0.9509460000000001, TP2: 0.969592, TP3: 0.9882380000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 TUSDUSDT - LONG Signal Detected at 0.9975
# Entry: 0.9975, Stop Loss: 0.9675750000000001, TP1: 1.01745, TP2: 1.0374, TP3: 1.05735
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 XLMUSDT - LONG Signal Detected at 0.3037
# Entry: 0.3037, Stop Loss: 0.294589, TP1: 0.30977400000000005, TP2: 0.315848, TP3: 0.32192200000000004
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 USDCUSDT - LONG Signal Detected at 1.0
# Entry: 1.0, Stop Loss: 0.97, TP1: 1.02, TP2: 1.04, TP3: 1.06
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LINKUSDT - LONG Signal Detected at 16.84
# Entry: 16.84, Stop Loss: 16.334799999999998, TP1: 17.1768, TP2: 17.5136, TP3: 17.8504
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 HOTUSDT - LONG Signal Detected at 0.00131
# Entry: 0.00131, Stop Loss: 0.0012706999999999998, TP1: 0.0013362, TP2: 0.0013624, TP3: 0.0013886
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZILUSDT - LONG Signal Detected at 0.01302
# Entry: 0.01302, Stop Loss: 0.0126294, TP1: 0.013280400000000001, TP2: 0.0135408, TP3: 0.013801200000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZRXUSDT - LONG Signal Detected at 0.2787
# Entry: 0.2787, Stop Loss: 0.270339, TP1: 0.284274, TP2: 0.289848, TP3: 0.295422
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 FETUSDT - LONG Signal Detected at 0.64
# Entry: 0.64, Stop Loss: 0.6208, TP1: 0.6528, TP2: 0.6656000000000001, TP3: 0.6784
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOSTUSDT - LONG Signal Detected at 0.004458
# Entry: 0.004458, Stop Loss: 0.00432426, TP1: 0.004547160000000001, TP2: 0.00463632, TP3: 0.004725480000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ALGOUSDT - LONG Signal Detected at 0.2469
# Entry: 0.2469, Stop Loss: 0.239493, TP1: 0.251838, TP2: 0.256776, TP3: 0.261714
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DOGEUSDT - LONG Signal Detected at 0.20608
# Entry: 0.20608, Stop Loss: 0.1998976, TP1: 0.21020160000000002, TP2: 0.21432320000000002, TP3: 0.21844480000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ANKRUSDT - LONG Signal Detected at 0.01938
# Entry: 0.01938, Stop Loss: 0.018798600000000002, TP1: 0.019767600000000003, TP2: 0.0201552, TP3: 0.020542800000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 WINUSDT - LONG Signal Detected at 6.215e-05
# Entry: 6.215e-05, Stop Loss: 6.0285500000000004e-05, TP1: 6.339300000000001e-05, TP2: 6.463600000000001e-05, TP3: 6.587900000000001e-05
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 COSUSDT - LONG Signal Detected at 0.004136
# Entry: 0.004136, Stop Loss: 0.0040119199999999995, TP1: 0.00421872, TP2: 0.00430144, TP3: 0.00438416
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 MTLUSDT - LONG Signal Detected at 0.82
# Entry: 0.82, Stop Loss: 0.7953999999999999, TP1: 0.8363999999999999, TP2: 0.8528, TP3: 0.8692
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DENTUSDT - LONG Signal Detected at 0.000817
# Entry: 0.000817, Stop Loss: 0.00079249, TP1: 0.00083334, TP2: 0.00084968, TP3: 0.0008660200000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BANDUSDT - LONG Signal Detected at 0.899
# Entry: 0.899, Stop Loss: 0.87203, TP1: 0.91698, TP2: 0.93496, TP3: 0.9529400000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 RVNUSDT - LONG Signal Detected at 0.01306
# Entry: 0.01306, Stop Loss: 0.0126682, TP1: 0.0133212, TP2: 0.013582400000000001, TP3: 0.013843600000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 NKNUSDT - LONG Signal Detected at 0.052
# Entry: 0.052, Stop Loss: 0.05044, TP1: 0.05304, TP2: 0.054079999999999996, TP3: 0.05512
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 STXUSDT - LONG Signal Detected at 0.728
# Entry: 0.728, Stop Loss: 0.70616, TP1: 0.74256, TP2: 0.75712, TP3: 0.77168
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 RLCUSDT - LONG Signal Detected at 1.204
# Entry: 1.204, Stop Loss: 1.16788, TP1: 1.22808, TP2: 1.25216, TP3: 1.27624
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 FTTUSDT - LONG Signal Detected at 1.4942
# Entry: 1.4942, Stop Loss: 1.449374, TP1: 1.524084, TP2: 1.553968, TP3: 1.583852
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 CTSIUSDT - LONG Signal Detected at 0.0831
# Entry: 0.0831, Stop Loss: 0.080607, TP1: 0.08476199999999999, TP2: 0.086424, TP3: 0.088086
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 CHRUSDT - LONG Signal Detected at 0.1111
# Entry: 0.1111, Stop Loss: 0.107767, TP1: 0.113322, TP2: 0.11554400000000001, TP3: 0.11776600000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ARDRUSDT - LONG Signal Detected at 0.0634
# Entry: 0.0634, Stop Loss: 0.061498, TP1: 0.064668, TP2: 0.065936, TP3: 0.067204
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 VTHOUSDT - LONG Signal Detected at 0.002726
# Entry: 0.002726, Stop Loss: 0.00264422, TP1: 0.0027805200000000003, TP2: 0.00283504, TP3: 0.0028895600000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DGBUSDT - LONG Signal Detected at 0.00847
# Entry: 0.00847, Stop Loss: 0.0082159, TP1: 0.0086394, TP2: 0.0088088, TP3: 0.0089782
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 SXPUSDT - LONG Signal Detected at 0.2104
# Entry: 0.2104, Stop Loss: 0.204088, TP1: 0.21460800000000002, TP2: 0.218816, TP3: 0.22302400000000003
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📜 Placed Trades:
# 🔹 Order 39132 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 49348 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 49771 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 BALUSDT - LONG Signal Detected at 1.688
# Entry: 1.688, Stop Loss: 1.63736, TP1: 1.72176, TP2: 1.75552, TP3: 1.78928
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 NMRUSDT - LONG Signal Detected at 9.11
# Entry: 9.11, Stop Loss: 8.836699999999999, TP1: 9.2922, TP2: 9.4744, TP3: 9.6566
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 DOTUSDT - LONG Signal Detected at 4.485
# Entry: 4.485, Stop Loss: 4.35045, TP1: 4.5747, TP2: 4.6644000000000005, TP3: 4.7541
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 PAXGUSDT - LONG Signal Detected at 2918.0
# Entry: 2918.0, Stop Loss: 2830.46, TP1: 2976.36, TP2: 3034.7200000000003, TP3: 3093.0800000000004
# ✅ Trade Executed: {'symbol': 'PAXGUSDT', 'orderId': 13762, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJae7b6f848a9a79005aedc', 'transactTime': 1741270410651, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '29.18000000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741270410651, 'fills': [{'price': '2918.00000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'PAXG', 'tradeId': 360}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 13706 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13707 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13761 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13762 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 454138 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 457107 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 397131 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 399235 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 400610 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 183127 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 QTUMUSDT - LONG Signal Detected at 2.344
# Entry: 2.344, Stop Loss: 2.2736799999999997, TP1: 2.39088, TP2: 2.43776, TP3: 2.48464
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 TUSDUSDT - LONG Signal Detected at 0.9975
# Entry: 0.9975, Stop Loss: 0.9675750000000001, TP1: 1.01745, TP2: 1.0374, TP3: 1.05735
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOTAUSDT - LONG Signal Detected at 0.2163
# Entry: 0.2163, Stop Loss: 0.209811, TP1: 0.220626, TP2: 0.224952, TP3: 0.229278
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ONTUSDT - LONG Signal Detected at 0.1591
# Entry: 0.1591, Stop Loss: 0.154327, TP1: 0.16228199999999998, TP2: 0.165464, TP3: 0.168646
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ICXUSDT - LONG Signal Detected at 0.1121
# Entry: 0.1121, Stop Loss: 0.108737, TP1: 0.11434200000000001, TP2: 0.11658400000000001, TP3: 0.11882600000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 NULSUSDT - LONG Signal Detected at 0.1526
# Entry: 0.1526, Stop Loss: 0.14802200000000001, TP1: 0.155652, TP2: 0.158704, TP3: 0.161756
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 HOTUSDT - LONG Signal Detected at 0.001305
# Entry: 0.001305, Stop Loss: 0.00126585, TP1: 0.0013311, TP2: 0.0013572, TP3: 0.0013833
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZILUSDT - LONG Signal Detected at 0.01298
# Entry: 0.01298, Stop Loss: 0.0125906, TP1: 0.0132396, TP2: 0.013499200000000001, TP3: 0.013758800000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ZRXUSDT - LONG Signal Detected at 0.2782
# Entry: 0.2782, Stop Loss: 0.269854, TP1: 0.283764, TP2: 0.28932800000000003, TP3: 0.29489200000000004
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 FETUSDT - LONG Signal Detected at 0.635
# Entry: 0.635, Stop Loss: 0.61595, TP1: 0.6477, TP2: 0.6604, TP3: 0.6731
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 IOSTUSDT - LONG Signal Detected at 0.00445
# Entry: 0.00445, Stop Loss: 0.0043165, TP1: 0.004539, TP2: 0.004628, TP3: 0.004717
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DASHUSDT - LONG Signal Detected at 24.74
# Entry: 24.74, Stop Loss: 23.997799999999998, TP1: 25.2348, TP2: 25.729599999999998, TP3: 26.2244
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 ENJUSDT - LONG Signal Detected at 0.1038
# Entry: 0.1038, Stop Loss: 0.100686, TP1: 0.10587600000000001, TP2: 0.107952, TP3: 0.11002800000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 ATOMUSDT - LONG Signal Detected at 4.366
# Entry: 4.366, Stop Loss: 4.23502, TP1: 4.45332, TP2: 4.54064, TP3: 4.62796
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 TFUELUSDT - LONG Signal Detected at 0.04268
# Entry: 0.04268, Stop Loss: 0.0413996, TP1: 0.043533600000000006, TP2: 0.0443872, TP3: 0.045240800000000005
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 150
#     148 scheduler.add_job(trading_bot, 'interval', minutes=5)
#     149 print("🚀 Trading bot started... Press Ctrl+C to stop.")
# --> 150 scheduler.start()
#
# File /opt/anaconda3/lib/python3.12/site-packages/apscheduler/schedulers/blocking.py:21, in BlockingScheduler.start(self, *args, **kwargs)
#      18     self._event = Event()
#      20 super(BlockingScheduler, self).start(*args, **kwargs)
# ---> 21 self._main_loop()
#
# File /opt/anaconda3/lib/python3.12/site-packages/apscheduler/schedulers/blocking.py:30, in BlockingScheduler._main_loop(self)
#      28 wait_seconds = TIMEOUT_MAX
#      29 while self.state != STATE_STOPPED:
# ---> 30     self._event.wait(wait_seconds)
#      31     self._event.clear()
#      32     wait_seconds = self._process_jobs()
#
# File /opt/anaconda3/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /opt/anaconda3/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# 📊 WANUSDT - LONG Signal Detected at 0.1214
# Entry: 0.1214, Stop Loss: 0.11775799999999999, TP1: 0.123828, TP2: 0.126256, TP3: 0.128684
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 BANDUSDT - LONG Signal Detected at 0.898
# Entry: 0.898, Stop Loss: 0.87106, TP1: 0.91596, TP2: 0.9339200000000001, TP3: 0.9518800000000001
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 RVNUSDT - LONG Signal Detected at 0.01305
# Entry: 0.01305, Stop Loss: 0.0126585, TP1: 0.013311000000000002, TP2: 0.013572, TP3: 0.013833000000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 NKNUSDT - LONG Signal Detected at 0.052
# Entry: 0.052, Stop Loss: 0.05044, TP1: 0.05304, TP2: 0.054079999999999996, TP3: 0.05512
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 TROYUSDT - LONG Signal Detected at 0.00132
# Entry: 0.00132, Stop Loss: 0.0012804, TP1: 0.0013464, TP2: 0.0013728, TP3: 0.0013992
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 FTTUSDT - LONG Signal Detected at 1.4932
# Entry: 1.4932, Stop Loss: 1.448404, TP1: 1.5230640000000002, TP2: 1.552928, TP3: 1.5827920000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 LSKUSDT - LONG Signal Detected at 0.616
# Entry: 0.616, Stop Loss: 0.5975199999999999, TP1: 0.62832, TP2: 0.64064, TP3: 0.65296
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 LTOUSDT - LONG Signal Detected at 0.0701
# Entry: 0.0701, Stop Loss: 0.06799699999999999, TP1: 0.071502, TP2: 0.072904, TP3: 0.074306
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DATAUSDT - LONG Signal Detected at 0.02016
# Entry: 0.02016, Stop Loss: 0.019555200000000002, TP1: 0.0205632, TP2: 0.020966400000000003, TP3: 0.021369600000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 SOLUSDT - LONG Signal Detected at 147.31
# Entry: 147.31, Stop Loss: 142.8907, TP1: 150.2562, TP2: 153.2024, TP3: 156.14860000000002
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: NOTIONAL
#
# 📊 CTSIUSDT - LONG Signal Detected at 0.083
# Entry: 0.083, Stop Loss: 0.08051, TP1: 0.08466, TP2: 0.08632000000000001, TP3: 0.08798
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 DGBUSDT - LONG Signal Detected at 0.00845
# Entry: 0.00845, Stop Loss: 0.008196499999999999, TP1: 0.008619, TP2: 0.008787999999999999, TP3: 0.008957
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📜 Placed Trades:
# 🔹 Order 39132 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📜 Placed Trades:
# 🔹 Order 49348 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 49771 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
#
# 📊 JSTUSDT - LONG Signal Detected at 0.03222
# Entry: 0.03222, Stop Loss: 0.0312534, TP1: 0.0328644, TP2: 0.0335088, TP3: 0.0341532
# ❌ Binance API Exception: APIError(code=-1013): Filter failure: LOT_SIZE
#
# 📊 PAXGUSDT - LONG Signal Detected at 2917.0
# Entry: 2917.0, Stop Loss: 2829.49, TP1: 2975.34, TP2: 3033.6800000000003, TP3: 3092.02
# ✅ Trade Executed: {'symbol': 'PAXGUSDT', 'orderId': 13802, 'orderListId': -1, 'clientOrderId': 'x-HNA2TXFJ6e9a64e8aa2d3d0117eac1', 'transactTime': 1741270710444, 'price': '0.00000000', 'origQty': '0.01000000', 'executedQty': '0.01000000', 'origQuoteOrderQty': '0.00000000', 'cummulativeQuoteQty': '29.17000000', 'status': 'FILLED', 'timeInForce': 'GTC', 'type': 'MARKET', 'side': 'BUY', 'workingTime': 1741270710444, 'fills': [{'price': '2917.00000000', 'qty': '0.01000000', 'commission': '0.00000000', 'commissionAsset': 'PAXG', 'tradeId': 364}], 'selfTradePreventionMode': 'EXPIRE_MAKER'}
#
# 📜 Placed Trades:
# 🔹 Order 13707 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13761 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13762 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13801 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
# 🔹 Order 13802 - BUY 0.01000000 at 0.00000000 (Status: FILLED)
